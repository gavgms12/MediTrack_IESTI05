# %%
import time 
import numpy as np
import matplotlib.pyplot as plt
from PIL import Image
import tflite_runtime.interpreter as tflite

from picamera2 import Picamera2

# %%
# !ls ../models/models_imgclass
# Out:
# ei-meditrack_iesti05_0-transfer-learning-tensorflow-lite-float32-model.3.lite
# ei-meditrack_iesti05_0-transfer-learning-tensorflow-lite-int8-quantized-model.3.lite

# %%
labels = ['background', 'cefalexina', 'cloridrato_de_ambroxol', 'sany_d']

# %%
model_path = '../models/models_imgclass/ei-meditrack_iesti05_0-transfer-learning-tensorflow-lite-float32-model.3.lite'
model_path_quantized = '../models/models_imgclass/ei-meditrack_iesti05_0-transfer-learning-tensorflow-lite-int8-quantized-model.3.lite'

# %%
def preprocess_image(img, input_details):
    target_size = (input_details[0]['shape'][1], input_details[0]['shape'][2])
    img = img.resize(target_size)
    input_dtype = input_details[0]['dtype']

    if input_dtype == np.uint8:
        return np.expand_dims(np.array(img), axis=0)
    
    elif input_dtype == np.int8:
        scale, zero_point = input_details[0]['quantization']
        img_array = np.array(img, dtype=np.float32)/255.0
        img_array = (img_array/scale + zero_point).clip(-128, 127).astype(np.int8)
        return np.expand_dims(img_array, axis=0)
    
    else:
        return np.expand_dims(np.array(img, dtype=np.float32), axis=0) / 255.0

# %%
def postprocess_output(predictions, output_details, apply_softmax=False):
    output_dtype = output_details[0]['dtype']
    if output_dtype in [np.int8, np.uint8]:
        scale, zero_point = output_details[0]['quantization']
        predictions = (predictions.astype(np.float32) - zero_point) * scale

    if apply_softmax:
        exp_preds = np.exp(predictions - np.max(predictions))
        predictions = exp_preds / np.sum(exp_preds)
    
    return predictions

# %%
def image_classification(img_path, model_path, labels, top_k_results=3, apply_softmax=False):
    img = Image.open(img_path)
    plt.figure(figsize=(4, 4))
    plt.imshow(img)
    plt.axis('off')

    interpreter = tflite.Interpreter(model_path=model_path)
    interpreter.allocate_tensors()
    input_details = interpreter.get_input_details()
    output_details = interpreter.get_output_details()

    input_data = preprocess_image(img, input_details)

    start_time = time.time()
    interpreter.set_tensor(input_details[0]['index'], input_data)
    interpreter.invoke()
    inference_time = (time.time() - start_time) * 1000

    predictions = interpreter.get_tensor(output_details[0]['index'])[0]
    predictions = postprocess_output(predictions, output_details, apply_softmax)
    
    print("\n[PREDICTION]        [Prob]\n")
    top_k_indices = np.argsort(predictions)[::-1][:top_k_results]
    for i in top_k_indices:
        print(f"{labels[i]:20}: {predictions[i]*100:.1f}%")
    print ("\n\tInference time: {:.1f}ms".format(inference_time))

# %%
img_path = '../data/dataset_imgclass/sany_d/image_20251018-080354.jpg'
image_classification(img_path, model_path, labels, top_k_results=len(labels))
# Out:
# /home/admin/tflite_env/lib/python3.11/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/admin/tflite_env/lib/python3.11/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# [PREDICTION]        [Prob]
#
# sany_d              : 100.0%
# cefalexina          : 0.0%
# cloridrato_de_ambroxol: 0.0%
# background          : 0.0%
#
# 	Inference time: 60.1ms

# %%
def capture_image(image_path):
    
  picam2 = Picamera2() 
  
  config = picam2.create_still_configuration(main={"size": (224, 224)})
  picam2.configure(config)
  picam2.start()

  time.sleep(8)
  
  picam2.capture_file(image_path)
  print("Image captured: "+image_path)

  picam2.stop()
  picam2.close()

# %%
img_path_camera = '../images/images_imgclass/img_path_camera.jpg'
capture_image(img_path_camera)
image_classification(img_path_camera, model_path, labels, top_k_results=len(labels))
# Out:
# [0:16:04.458122465] [3027]  INFO Camera camera_manager.cpp:326 libcamera v0.5.1+100-e53bdf1f
# [0:16:04.558054028] [3059]  WARN RPiSdn sdn.cpp:40 Using legacy SDN tuning - please consider moving SDN inside rpi.denoise
# [0:16:04.566502771] [3059]  INFO RPI vc4.cpp:440 Registered camera /base/soc/i2c0mux/i2c@1/ov5647@36 to Unicam device /dev/media0 and ISP device /dev/media1
# [0:16:04.566659330] [3059]  INFO RPI pipeline_base.cpp:1107 Using configuration file '/usr/share/libcamera/pipeline/rpi/vc4/rpi_apps.yaml'
# [0:16:04.589559845] [3027]  INFO Camera camera.cpp:1205 configuring streams: (0) 224x224-BGR888/sRGB (1) 640x480-SGBRG10_CSI2P/RAW
# [0:16:04.590446698] [3059]  INFO RPI vc4.cpp:615 Sensor: /base/soc/i2c0mux/i2c@1/ov5647@36 - Selected sensor format: 640x480-SGBRG10_1X10 - Selected unicam format: 640x480-pGAA
# Image captured: ../images/images_imgclass/img_path_camera.jpg
#
# [PREDICTION]        [Prob]
#
# cloridrato_de_ambroxol: 95.5%
# cefalexina          : 4.5%
# sany_d              : 0.0%
# background          : 0.0%
#
# 	Inference time: 35.7ms
